# %%
def strList_into_floatList(L):
    L2 = []
    for l in L:
        L2.append(float(l))
    return L2

def save_(title):
    return plt.savefig('/Users/rubenexojo/Library/Mobile Documents/com~apple~CloudDocs/MSc Mathematical Finance - Manchester/subjects/II_semester/MATH60082_computational_finance/c++/assignment2/tex/img/' + title + '.png', format='png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
## OPEN THE DATA FRAME
df = pd.read_csv("/Users/rubenexojo/Library/Mobile Documents/com~apple~CloudDocs/MSc Mathematical Finance - Manchester/subjects/II_semester/MATH60082_computational_finance/c++/assignment2/data/eurConvBondValues.csv")
## KEEP DATA IN A LIST
F = df['F'].tolist()
S = df['S'].tolist()
V = strList_into_floatList(df['V'].tolist())
VtoINF = df['VtoINF']
## LATIN MODERN
# %pylab inline
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)
## OPEN A FIGURE
figure(num=None, figsize=(10, 6), dpi=70, facecolor='w', edgecolor='k')
## GRID   
plt.grid(color='k', linestyle='-.', linewidth=0.05)
## PLOT THE SOLUTION
plt.plot(S,V, color='orange',label=r"$V(S,t=0)$")
plt.plot(S,VtoINF, color='olive', label=r"$S A(0) + B(0)$")
plt.plot(S,F, color='k', linestyle='--', linewidth=0.5, label=r"$F$")
## LEGEND
plt.legend(loc="lower right", fontsize=15)
## LABELS
plt.xlabel(r'$S$', labelpad=20, fontsize=16)
plt.ylabel(r'$V(S,t=0)$', labelpad=20, fontsize=16)
save_('test')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Text(0, 0.5, '$V(S,t=0)$')
